# %%
# Imports
import pandas as pd
#import numpy as np

# %% [markdown]
# ### 1. Import data and DF creation

# %%
json_path = "../data/dades_amb_emails.json"

#input_csv = pd.read_csv(json_path, sep=",")
input_json = pd.read_json(json_path)

input_json.head(5)
#input_csv.head(5)
# Out:
#                                          name     category  \
# 0                    Canapé Premium Music Bar  Bar musical
# 1  The Secret Garden Restaurant & Lounge Club  Restaurante
# 2                                 NIGHT & DAY          Pub
# 3                            Los Panda Lounge       Lounge
# 4                             Sala Razzmatazz    Discoteca
#
#                                              address                website  \
# 0  Carrer de la Muntanya, 34, Sant Martí, 08026 B...             NO_WEBSITE
# 1  Carrer de Salvador Espriu, 79, Sant Martí, 080...  thesecretgardenbcn.es
# 2  Carrer dels Almogàvers, 62, Sant Martí, 08018 ...              linktr.ee
# 3  Carrer de la Independència, 326, Sant Martí, 0...           facebook.com
# 4  Carrer dels Almogàvers, 122, Sant Martí, 08018...     salarazzmatazz.com
#
#        phone       city   auxiliar reviews_rating num_reviews  \
# 0   NO_PHONE    NO_CITY  NOT_FOUND            3.9         428
# 1  641464872  Barcelona      Carta            4.7         456
# 2  622380323    NO_CITY      Carta            4.2         410
# 3  634244970  Barcelona  NOT_FOUND            4.8          60
# 4  933208200  Barcelona  NOT_FOUND            4.2       20729
#
#                                          description  \
# 0                                          NOT_FOUND
# 1                                          NOT_FOUND
# 2  Discoteca con zona de sofás tipo chill out más...
# 3                                          NOT_FOUND
# 4  Cervezas y copas en una animada discoteca que ...
#
#                                             schedule  \
# 0  [{'day': 'viernes', 'hours': '21:00–3:30'}, {'...
# 1  [{'day': 'viernes', 'hours': '20:00–3:00'}, {'...
# 2  [{'day': 'viernes', 'hours': '20:00–4:00'}, {'...
# 3  [{'day': 'viernes', 'hours': '11:00–14:0016:00...
# 4  [{'day': 'viernes', 'hours': '0:30–5:00'}, {'d...
#
#                                                 img1  \
# 0  https://lh5.googleusercontent.com/p/AF1QipN98e...
# 1  https://lh5.googleusercontent.com/p/AF1QipMvah...
# 2  https://lh5.googleusercontent.com/p/AF1QipMoPG...
# 3  https://lh5.googleusercontent.com/p/AF1QipMjPK...
# 4  https://lh5.googleusercontent.com/p/AF1QipN4W2...
#
#                                                 img2     email
# 0  https://lh5.googleusercontent.com/p/AF1QipPLLv...       NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipNKHn...  NO_EMAIL
# 2  https://lh5.googleusercontent.com/p/AF1QipMoPG...  NO_EMAIL
# 3  https://lh5.googleusercontent.com/p/AF1QipMjPK...  NO_EMAIL
# 4  https://lh5.googleusercontent.com/p/AF1QipMIjj...  NO_EMAIL

# %% [markdown]
# ### 2. Prepare DataFrame

# %%
main_df = input_json.copy()

main_df = main_df.reset_index(drop=True)
main_df.index += 1
#main_df.head()

# %%
# Drop row if num_reviews or reviews_rating is "NOT_FOUND"
main_df = main_df[main_df['num_reviews'] != "NOT_FOUND"]
main_df = main_df[main_df['reviews_rating'] != "NOT_FOUND"]

# Change num_reviews and reviews_rating to int and float
main_df['num_reviews'] = main_df['num_reviews'].astype(int)
main_df['reviews_rating'] = main_df['reviews_rating'].astype(float)

# %%
# Sort by number of reviews
main_df = main_df.sort_values(by='num_reviews', ascending=False)

# %%
# Rename auxiliar column
main_df = main_df.rename(columns={"auxiliar": "auxiliar(borrar)"})

# Reorder columns
main_df = main_df.iloc[:, [0, 1, 5, 2, 3, 13, 4, 7, 8, 9, 10, 6, 11, 12]]

# %%
# Selecciona las columnas a considerar (excluyendo 'schedule' y 'name')
subset_columns = [col for col in main_df.columns if col not in ['schedule', 'name']]

# Elimina duplicados solo usando las columnas seleccionadas
main_df = main_df.drop_duplicates(subset=subset_columns)

# %%
print(main_df.dtypes)
# Out:
# name                 object
# category             object
# city                 object
# address              object
# website              object
# email                object
# phone                object
# reviews_rating      float64
# num_reviews           int32
# description          object
# schedule             object
# auxiliar(borrar)     object
# img1                 object
# img2                 object
# dtype: object

# %%
main_df
# Out:
#                                           name             category  \
# 5                              Sala Razzmatazz            Discoteca
# 6                               Wolf Barcelona            Discoteca
# 14                         Otto Zutz Barcelona            Discoteca
# 9                Touch Music Karaoke BARCELONA              Karaoke
# 13                             Magic Barcelona  Club de música rock
# 11                            Arena Experience            Discoteca
# 18                    Madame George Lounge Bar           Coctelería
# 30                                    Almirall                  Bar
# 2   The Secret Garden Restaurant & Lounge Club          Restaurante
# 1                     Canapé Premium Music Bar          Bar musical
# 3                                  NIGHT & DAY                  Pub
# 16                     El Cinco Club Barcelona            Discoteca
# 15                            Blue Space Aragó          Bar musical
# 12                                  Garage 442          Bar musical
# 10                               56 Lounge Bar               Lounge
# 4                             Los Panda Lounge               Lounge
# 17                           Club La Bombonera        Club nocturno
# 19                                Bar Caramelo          Bar musical
# 8                              GIN CLUB SCOTCH        Club nocturno
# 21                                      Bóveda            NOT_FOUND
# 7                                  Nave La Pau        Club nocturno
# 22                            GREENSTATION BCN            NOT_FOUND
#
#          city                                            address  \
# 5   Barcelona  Carrer dels Almogàvers, 122, Sant Martí, 08018...
# 6   Barcelona  Carrer dels Almogàvers, 88, Sant Martí, 08018 ...
# 14  Barcelona  Carrer de Lincoln, 15, Sarrià-Sant Gervasi, 08...
# 9   Barcelona  Carrer de Joan Miró, 8, Sant Martí, 08005 Barc...
# 13  Barcelona  Passeig de Picasso, 40, Ciutat Vella, 08003 Ba...
# 11  Barcelona   Rda. de Sant Pere, 21, Eixample, 08010 Barcelona
# 18  Barcelona  Carrer de Pujades, 179, Sant Martí, 08005 Barc...
# 30  Barcelona   Carrer d'Aragó, 625, Sant Martí, 08026 Barcelona
# 2   Barcelona  Carrer de Salvador Espriu, 79, Sant Martí, 080...
# 1     NO_CITY  Carrer de la Muntanya, 34, Sant Martí, 08026 B...
# 3     NO_CITY  Carrer dels Almogàvers, 62, Sant Martí, 08018 ...
# 16    NO_CITY  Plaça de Joan Llongueras, 5, Sarrià-Sant Gerva...
# 15  Barcelona   Carrer d'Aragó, 595, Sant Martí, 08026 Barcelona
# 12  Barcelona     Av. Diagonal, 442, L'Eixample, 08037 Barcelona
# 10    NO_CITY  Carrer de la Marina, 56, Sant Martí, 08005 Bar...
# 4   Barcelona  Carrer de la Independència, 326, Sant Martí, 0...
# 17    NO_CITY  Carrer de Nàpols, 173, L'Eixample, 08013 Barce...
# 19    NO_CITY    Carrer Bassols, 13, Sant Martí, 08018 Barcelona
# 8     NO_CITY  Carrer de Mallorca, 579, Sant Martí, 08026 Bar...
# 21    NO_CITY  Carrer de Pallars, 97, Sant Martí, 08018 Barce...
# 7     NO_CITY   Rambla de Prim, 263, Sant Martí, 08020 Barcelona
# 22    NO_CITY  Carrer del Consell de Cent, 597, Sant Martí, 0...
#
#                   website                            email      phone  \
# 5      salarazzmatazz.com                         NO_EMAIL  933208200
# 6       wolfbarcelona.com                         NO_EMAIL  672707844
# 14           ottozutz.com                         NO_EMAIL  669266410
# 9          karaokebcn.com  touchmusic@karaokebarcelona.com   NO_PHONE
# 13         magic-club.net                         NO_EMAIL  933107267
# 11         grupoarena.com                         NO_EMAIL  934875140
# 18    madamegeorgebar.com                         NO_EMAIL  935005151
# 30           facebook.com                         NO_EMAIL  677575868
# 2   thesecretgardenbcn.es                         NO_EMAIL  641464872
# 1              NO_WEBSITE                              NaN   NO_PHONE
# 3               linktr.ee                         NO_EMAIL  622380323
# 16      elcinco.barcelona                         NO_EMAIL  938580813
# 15           facebook.com                         NO_EMAIL  605153636
# 12          garage442.com                         NO_EMAIL  934152231
# 10             NO_WEBSITE                              NaN   NO_PHONE
# 4            facebook.com                         NO_EMAIL  634244970
# 17             NO_WEBSITE                              NaN   NO_PHONE
# 19             NO_WEBSITE                              NaN   NO_PHONE
# 8              NO_WEBSITE                              NaN   NO_PHONE
# 21             NO_WEBSITE                              NaN   NO_PHONE
# 7              NO_WEBSITE                              NaN   NO_PHONE
# 22             NO_WEBSITE                              NaN   NO_PHONE
#
#     reviews_rating  num_reviews  \
# 5              4.2        20729
# 6              4.3         7674
# 14             3.2         4982
# 9              4.5         3733
# 13             3.9         1115
# 11             3.8         1066
# 18             4.4          802
# 30             3.8          540
# 2              4.7          456
# 1              3.9          428
# 3              4.2          410
# 16             3.8          361
# 15             3.9          281
# 12             4.3          227
# 10             4.0          149
# 4              4.8           60
# 17             3.5           29
# 19             4.7           14
# 8              2.5            4
# 21             5.0            2
# 7              5.0            1
# 22             5.0            1
#
#                                           description  \
# 5   Cervezas y copas en una animada discoteca que ...
# 6                                           NOT_FOUND
# 14  Discoteca con varias salas e iluminación ambie...
# 9   Bar karaoke con un escenario tradicional al fo...
# 13  Mítica y concurrida sala de conciertos donde s...
# 11                                          NOT_FOUND
# 18                                          NOT_FOUND
# 30                                          NOT_FOUND
# 2                                           NOT_FOUND
# 1                                           NOT_FOUND
# 3   Discoteca con zona de sofás tipo chill out más...
# 16                                          NOT_FOUND
# 15  Bar animado, con DJ, narguiles y cócteles clás...
# 12                                          NOT_FOUND
# 10                                          NOT_FOUND
# 4                                           NOT_FOUND
# 17                                          NOT_FOUND
# 19                                          NOT_FOUND
# 8                                           NOT_FOUND
# 21                                          NOT_FOUND
# 7                                           NOT_FOUND
# 22                                          NOT_FOUND
#
#                                              schedule  \
# 5   [{'day': 'viernes', 'hours': '0:30–5:00'}, {'d...
# 6   [{'day': 'viernes', 'hours': '0:00–5:00'}, {'d...
# 14  [{'day': 'viernes', 'hours': '0:00–5:0023:55–2...
# 9                                           NOT_FOUND
# 13  [{'day': 'viernes', 'hours': '0:00–4:4523:00–2...
# 11  [{'day': 'viernes', 'hours': '0:00–5:0023:59–2...
# 18  [{'day': 'viernes', 'hours': '18:00–3:00'}, {'...
# 30  [{'day': 'viernes', 'hours': '8:30–2:30'}, {'d...
# 2   [{'day': 'viernes', 'hours': '20:00–3:00'}, {'...
# 1   [{'day': 'viernes', 'hours': '21:00–3:30'}, {'...
# 3   [{'day': 'viernes', 'hours': '20:00–4:00'}, {'...
# 16  [{'day': 'viernes', 'hours': '0:00–5:0023:55–2...
# 15  [{'day': 'viernes', 'hours': '21:00–3:30'}, {'...
# 12  [{'day': 'viernes', 'hours': '22:30–3:00'}, {'...
# 10  [{'day': 'viernes', 'hours': '16:00–3:00'}, {'...
# 4   [{'day': 'viernes', 'hours': '11:00–14:0016:00...
# 17  [{'day': 'viernes', 'hours': '19:00–5:00'}, {'...
# 19  [{'day': 'viernes', 'hours': '17:00–3:00'}, {'...
# 8   [{'day': 'viernes', 'hours': '21:00–5:00'}, {'...
# 21                                          NOT_FOUND
# 7   [{'day': 'viernes', 'hours': 'Cerrado'}, {'day...
# 22                                          NOT_FOUND
#
#                     auxiliar(borrar)  \
# 5                          NOT_FOUND
# 6   Amigable con la comunidad LGTBI+
# 14  Amigable con la comunidad LGTBI+
# 9          Cerrado ⋅ Apertura: 22:00
# 13                         NOT_FOUND
# 11  Amigable con la comunidad LGTBI+
# 18  Amigable con la comunidad LGTBI+
# 30             Reclamar esta empresa
# 2                              Carta
# 1                          NOT_FOUND
# 3                              Carta
# 16                 Reservar una mesa
# 15                         NOT_FOUND
# 12  Amigable con la comunidad LGTBI+
# 10                         NOT_FOUND
# 4                          NOT_FOUND
# 17                         NOT_FOUND
# 19                         NOT_FOUND
# 8                          NOT_FOUND
# 21                         NOT_FOUND
# 7                          NOT_FOUND
# 22                         NOT_FOUND
#
#                                                  img1  \
# 5   https://lh5.googleusercontent.com/p/AF1QipN4W2...
# 6   https://lh5.googleusercontent.com/p/AF1QipPA8F...
# 14  https://lh5.googleusercontent.com/p/AF1QipMoN2...
# 9   https://lh5.googleusercontent.com/p/AF1QipOfxl...
# 13  https://lh5.googleusercontent.com/p/AF1QipMLux...
# 11  https://lh5.googleusercontent.com/p/AF1QipPJ8-...
# 18  https://lh5.googleusercontent.com/p/AF1QipOtu6...
# 30  https://lh5.googleusercontent.com/p/AF1QipMIC2...
# 2   https://lh5.googleusercontent.com/p/AF1QipMvah...
# 1   https://lh5.googleusercontent.com/p/AF1QipN98e...
# 3   https://lh5.googleusercontent.com/p/AF1QipMoPG...
# 16  https://lh5.googleusercontent.com/p/AF1QipNR1E...
# 15  https://lh5.googleusercontent.com/p/AF1QipPnDP...
# 12  https://lh5.googleusercontent.com/p/AF1QipN9Hs...
# 10  https://lh5.googleusercontent.com/p/AF1QipOlih...
# 4   https://lh5.googleusercontent.com/p/AF1QipMjPK...
# 17  https://lh5.googleusercontent.com/p/AF1QipNm8a...
# 19  https://lh5.googleusercontent.com/p/AF1QipMdym...
# 8   https://lh5.googleusercontent.com/p/AF1QipNE6N...
# 21  https://streetviewpixels-pa.googleapis.com/v1/...
# 7   https://streetviewpixels-pa.googleapis.com/v1/...
# 22  https://streetviewpixels-pa.googleapis.com/v1/...
#
#                                                  img2
# 5   https://lh5.googleusercontent.com/p/AF1QipMIjj...
# 6   https://lh3.googleusercontent.com/p/AF1QipOyB3...
# 14  https://lh5.googleusercontent.com/p/AF1QipOGeC...
# 9   https://lh5.googleusercontent.com/p/AF1QipNF9W...
# 13  https://lh5.googleusercontent.com/p/AF1QipNSVB...
# 11  https://lh5.googleusercontent.com/p/AF1QipPB2g...
# 18  https://lh5.googleusercontent.com/p/AF1QipMVgh...
# 30  https://lh5.googleusercontent.com/p/AF1QipMNRq...
# 2   https://lh5.googleusercontent.com/p/AF1QipNKHn...
# 1   https://lh5.googleusercontent.com/p/AF1QipPLLv...
# 3   https://lh5.googleusercontent.com/p/AF1QipMoPG...
# 16  https://lh5.googleusercontent.com/p/AF1QipOSJk...
# 15  https://lh5.googleusercontent.com/p/AF1QipN8b0...
# 12  https://lh5.googleusercontent.com/p/AF1QipPtkz...
# 10  https://lh5.googleusercontent.com/p/AF1QipNnwp...
# 4   https://lh5.googleusercontent.com/p/AF1QipMjPK...
# 17  https://lh5.googleusercontent.com/p/AF1QipNm8a...
# 19  https://lh5.googleusercontent.com/p/AF1QipMdym...
# 8   https://lh5.googleusercontent.com/p/AF1QipNE6N...
# 21  https://streetviewpixels-pa.googleapis.com/v1/...
# 7   https://streetviewpixels-pa.googleapis.com/v1/...
# 22  https://streetviewpixels-pa.googleapis.com/v1/...

# %% [markdown]
# ### 3. Export DataFrame to CSV and JSON

# %%
df = main_df.copy()

# %%
# --- Save to CSV ---
output_path_csv = "../data/dades_netes.csv"
df.to_csv(output_path_csv, index=False)

# %%
# --- Save to JSON ---
output_path_json = "../data/dades_netes.json"
df.to_json(output_path_json, index=False)
