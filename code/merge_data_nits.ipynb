# %%
# Imports
import pandas as pd
#import numpy as np

# %% [markdown]
# ### 1. Import all datasets

# %%
json_path_eixample = "../data/eixample/dades_netes.json"
json_path_gracia = "../data/gracia/dades_netes.json"
json_path_santandreu = "../data/sant andreu/dades_netes.json"
json_path_santmarti = "../data/sant marti/dades_netes.json"
json_path_sants = "../data/sants/dades_netes.json"
json_path_sarria = "../data/sarria/dades_netes.json"

json_path_hospitalet = "../data/hospitalet/dades_netes.json"

# %%
input_eixample = pd.read_json(json_path_eixample)
input_gracia = pd.read_json(json_path_gracia)
input_santandreu = pd.read_json(json_path_santandreu)
input_santmarti = pd.read_json(json_path_santmarti)
input_sants = pd.read_json(json_path_sants)
input_sarria = pd.read_json(json_path_sarria)

input_hospitalet = pd.read_json(json_path_hospitalet)

#input_eixample.dtypes

# %% [markdown]
# ### 2. Merge all datasets

# %%
input_data = pd.concat([input_eixample, input_gracia, input_santandreu, input_santmarti, input_sants, input_sarria, input_hospitalet])

print(input_data.shape)
# Out:
# (203, 12)

# %% [markdown]
# ### 3. Data Processing

# %%
df = input_data.copy()

df = df.reset_index(drop=True)

# %%
# Drop duplicates
subset_columns = [col for col in df.columns if col not in ['schedule', 'name']]
df = df.drop_duplicates(subset=subset_columns)

# Sort by number of reviews
df = df.sort_values(by='num_reviews', ascending=False)

# %%
df
# Out:
#                               name       category       city  \
# 108                Sala Razzmatazz      Discoteca  Barcelona
# 109                 Wolf Barcelona      Discoteca  Barcelona
# 84           Cocteleria Torre Rosa     Coctelería  Barcelona
# 110  Touch Music Karaoke BARCELONA        Karaoke  Barcelona
# 0                   Slow Barcelona      Discoteca    NO_CITY
# ..                             ...            ...        ...
# 128               GREENSTATION BCN      NOT_FOUND    NO_CITY
# 127                    Nave La Pau  Club nocturno    NO_CITY
# 83                       Carolines  Club nocturno  Barcelona
# 107                    Meduza Club      Discoteca  Barcelona
# 202      Bar Musical Punta Dulce 2    Bar musical    NO_CITY
#
#                                                address  \
# 108  Carrer dels Almogàvers, 122, Sant Martí, 08018...
# 109  Carrer dels Almogàvers, 88, Sant Martí, 08018 ...
# 84   Carrer de Francesc Tàrrega, 22, Sant Andreu, 0...
# 110  Carrer de Joan Miró, 8, Sant Martí, 08005 Barc...
# 0    Carrer de París, 186, L'Eixample, 08036 Barcelona
# ..                                                 ...
# 128  Carrer del Consell de Cent, 597, Sant Martí, 0...
# 127   Rambla de Prim, 263, Sant Martí, 08020 Barcelona
# 83                                           NOT_FOUND
# 107  Carrer del Taquígraf Serra, 18, Les Corts, 080...
# 202  Carrer de la Renclusa, 32, 08905 L'Hospitalet ...
#
#                                       website  \
# 108                        salarazzmatazz.com
# 109                         wolfbarcelona.com
# 84                              torrerosa.com
# 110                            karaokebcn.com
# 0                            slowbarcelona.es
# ..                                        ...
# 128                                NO_WEBSITE
# 127                                NO_WEBSITE
# 83   Pl. del Diamant, Gràcia, 08012 Barcelona
# 107                           meduzagirls.com
# 202                                NO_WEBSITE
#
#                                email      phone  reviews_rating  num_reviews  \
# 108                         NO_EMAIL  933208200             4.2        20606
# 109                         NO_EMAIL  672707844             4.3         7511
# 84                          NO_EMAIL  933408854             4.4         4996
# 110  touchmusic@karaokebarcelona.com   NO_PHONE             4.5         3583
# 0              info@slowbarcelona.es  933681455             4.5         3439
# ..                               ...        ...             ...          ...
# 128                             None   NO_PHONE             5.0            1
# 127                             None   NO_PHONE             5.0            1
# 83                          NO_EMAIL   NO_PHONE             3.0            1
# 107                   info@meduza.es  687039240             5.0            1
# 202                             None   NO_PHONE             5.0            1
#
#                                            description  \
# 108  Cervezas y copas en una animada discoteca que ...
# 109                                          NOT_FOUND
# 84   Coctelería sencilla y acogedora, ubicada en un...
# 110  Bar karaoke con un escenario tradicional al fo...
# 0    Cócteles clásicos y personalizados, música en ...
# ..                                                 ...
# 128                                          NOT_FOUND
# 127                                          NOT_FOUND
# 83                                           NOT_FOUND
# 107                                          NOT_FOUND
# 202                                          NOT_FOUND
#
#                                               schedule  \
# 108  [{'day': 'viernes', 'hours': '0:30–5:00'}, {'d...
# 109  [{'day': 'viernes', 'hours': '0:00–5:00'}, {'d...
# 84   [{'day': 'viernes', 'hours': '18:00–3:00'}, {'...
# 110                                          NOT_FOUND
# 0    [{'day': 'viernes', 'hours': '0:00–5:0019:00–2...
# ..                                                 ...
# 128                                          NOT_FOUND
# 127  [{'day': 'viernes', 'hours': 'Cerrado'}, {'day...
# 83                                           NOT_FOUND
# 107  [{'day': 'viernes', 'hours': 'Abierto 24 horas...
# 202  [{'day': 'lunes', 'hours': '20:00–3:00'}, {'da...
#
#                      auxiliar(borrar)
# 108                         NOT_FOUND
# 109  Amigable con la comunidad LGTBI+
# 84                               Menú
# 110         Cerrado ⋅ Apertura: 22:00
# 0                                Menú
# ..                                ...
# 128                         NOT_FOUND
# 127                         NOT_FOUND
# 83                          NOT_FOUND
# 107                         NOT_FOUND
# 202                         NOT_FOUND
#
# [186 rows x 12 columns]

# %% [markdown]
# ### 4. Export data

# %%
# --- Save to CSV ---
output_path_csv = "../data/dades_finals.csv"
df.to_csv(output_path_csv, index=False)

# %%
# --- Save to JSON ---
output_path_json = "../data/dades_finals.json"
df.to_json(output_path_json, orient='records')
